# %% [markdown]
# <a href="https://colab.research.google.com/github/innosoft21/workspace/blob/main/tensorflow_python/Kaggle_classify_Dog_Cat_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

# %%
dataset_name = 'cats_vs_dogs'
dataset, info= tfds.load(name=dataset_name, split=tfds.Split.TRAIN, with_info=True)
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incomplete41PMLC/cats_vs_dogs-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=23262.0), HTML(value='')))
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
def preprocess(features):
    print(features['image'], features['label'])
    image = tf.image.resize(features['image'], [224,224])
    image = tf.divide(image, 255)
    print(image)
    label = features['label']
    print(label)
    return image, label

# %%
def solution_model():
    train_dataset = dataset.map(preprocess).batch(32)

    model = tf.keras.Sequential( 
        [
            tf.keras.layers.Conv2D(16, (3, 3), input_shape=(224, 224, 3), activation='relu'),
            tf.keras.layers.MaxPool2D(2, 2),
            tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
            tf.keras.layers.MaxPool2D(2, 2),
            tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
            tf.keras.layers.MaxPool2D(2, 2),
            tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
            tf.keras.layers.MaxPool2D(2, 2),
            tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
            tf.keras.layers.MaxPool2D(2, 2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(1024, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(1, activation='softmax')
        ]
    )
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    history = model.fit(train_dataset, epochs=100, verbose= 2)

    return model

# %%
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Tensor("args_0:0", shape=(None, None, 3), dtype=uint8) Tensor("args_2:0", shape=(), dtype=int64)
# Tensor("truediv:0", shape=(224, 224, 3), dtype=float32)
# Tensor("args_2:0", shape=(), dtype=int64)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 32)        36896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              820224
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 955,585
# Trainable params: 955,585
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 727/727 - 63s - loss: 0.6273 - accuracy: 0.4988
# Epoch 2/100
# 727/727 - 30s - loss: 0.4972 - accuracy: 0.4988
# Epoch 3/100
# 727/727 - 30s - loss: 0.4041 - accuracy: 0.4988
# Epoch 4/100
# 727/727 - 30s - loss: 0.3306 - accuracy: 0.4988
# Epoch 5/100
# 727/727 - 30s - loss: 0.2759 - accuracy: 0.4988
# Epoch 6/100
# 727/727 - 30s - loss: 0.2352 - accuracy: 0.4988
# Epoch 7/100
# 727/727 - 30s - loss: 0.1998 - accuracy: 0.4988
# Epoch 8/100
# 727/727 - 30s - loss: 0.1741 - accuracy: 0.4988
# Epoch 9/100
# 727/727 - 30s - loss: 0.1538 - accuracy: 0.4988
# Epoch 10/100
# 727/727 - 30s - loss: 0.1340 - accuracy: 0.4988
# Epoch 11/100
# 727/727 - 30s - loss: 0.1224 - accuracy: 0.4988
# Epoch 12/100
# 727/727 - 30s - loss: 0.1132 - accuracy: 0.4988
# Epoch 13/100
# 727/727 - 30s - loss: 0.0948 - accuracy: 0.4988
# Epoch 14/100
# 727/727 - 30s - loss: 0.0836 - accuracy: 0.4988
# Epoch 15/100
# 727/727 - 30s - loss: 0.0769 - accuracy: 0.4988
# Epoch 16/100
# 727/727 - 30s - loss: 0.0706 - accuracy: 0.4988
# Epoch 17/100
# 727/727 - 30s - loss: 0.0710 - accuracy: 0.4988
# Epoch 18/100
# 727/727 - 30s - loss: 0.0586 - accuracy: 0.4988
# Epoch 19/100
# 727/727 - 31s - loss: 0.0653 - accuracy: 0.4988
# Epoch 20/100
# 727/727 - 32s - loss: 0.0557 - accuracy: 0.4988
# Epoch 21/100
# 727/727 - 31s - loss: 0.0649 - accuracy: 0.4988
# Epoch 22/100
# 727/727 - 31s - loss: 0.0490 - accuracy: 0.4988
# Epoch 23/100
# 727/727 - 31s - loss: 0.0549 - accuracy: 0.4988
# Epoch 24/100
# 727/727 - 31s - loss: 0.0511 - accuracy: 0.4988
# Epoch 25/100
# 727/727 - 31s - loss: 0.0437 - accuracy: 0.4988
# Epoch 26/100
# 727/727 - 31s - loss: 0.0392 - accuracy: 0.4988
# Epoch 27/100
# 727/727 - 31s - loss: 0.0460 - accuracy: 0.4988
# Epoch 28/100
# 727/727 - 31s - loss: 0.0431 - accuracy: 0.4988
# Epoch 29/100
# 727/727 - 30s - loss: 0.0401 - accuracy: 0.4988
# Epoch 30/100
# 727/727 - 30s - loss: 0.0463 - accuracy: 0.4988
# Epoch 31/100
# 727/727 - 30s - loss: 0.0385 - accuracy: 0.4988
# Epoch 32/100
# 727/727 - 30s - loss: 0.0457 - accuracy: 0.4988
# Epoch 33/100
# 727/727 - 31s - loss: 0.0350 - accuracy: 0.4988
# Epoch 34/100
# 727/727 - 31s - loss: 0.0321 - accuracy: 0.4988
# Epoch 35/100
# 727/727 - 31s - loss: 0.0409 - accuracy: 0.4988
# Epoch 36/100
# 727/727 - 31s - loss: 0.0397 - accuracy: 0.4988
# Epoch 37/100
# 727/727 - 31s - loss: 0.0392 - accuracy: 0.4988
# Epoch 38/100
# 727/727 - 30s - loss: 0.0443 - accuracy: 0.4988
# Epoch 39/100
# 727/727 - 30s - loss: 0.0388 - accuracy: 0.4988
# Epoch 40/100
# 727/727 - 30s - loss: 0.0408 - accuracy: 0.4988
# Epoch 41/100
# 727/727 - 31s - loss: 0.0367 - accuracy: 0.4988
# Epoch 42/100
# 727/727 - 30s - loss: 0.0369 - accuracy: 0.4988
# Epoch 43/100
# 727/727 - 30s - loss: 0.0329 - accuracy: 0.4988
# Epoch 44/100
# 727/727 - 30s - loss: 0.0286 - accuracy: 0.4988
# Epoch 45/100
# 727/727 - 30s - loss: 0.0298 - accuracy: 0.4988
# Epoch 46/100
# 727/727 - 30s - loss: 0.0469 - accuracy: 0.4988
# Epoch 47/100
# 727/727 - 30s - loss: 0.0339 - accuracy: 0.4988
# Epoch 48/100
# 727/727 - 30s - loss: 0.0391 - accuracy: 0.4988
# Epoch 49/100
# 727/727 - 31s - loss: 0.0314 - accuracy: 0.4988
# Epoch 50/100
# 727/727 - 31s - loss: 0.0308 - accuracy: 0.4988
# Epoch 51/100
# 727/727 - 31s - loss: 0.0338 - accuracy: 0.4988
# Epoch 52/100
# 727/727 - 31s - loss: 0.0338 - accuracy: 0.4988
# Epoch 53/100
# 727/727 - 30s - loss: 0.0322 - accuracy: 0.4988
# Epoch 54/100
# 727/727 - 30s - loss: 0.0421 - accuracy: 0.4988
# Epoch 55/100
# 727/727 - 30s - loss: 0.0389 - accuracy: 0.4988
# Epoch 56/100
# 727/727 - 30s - loss: 0.0303 - accuracy: 0.4988
# Epoch 57/100
# 727/727 - 30s - loss: 0.0327 - accuracy: 0.4988
# Epoch 58/100
# 727/727 - 30s - loss: 0.0385 - accuracy: 0.4988
# Epoch 59/100
# 727/727 - 30s - loss: 0.0273 - accuracy: 0.4988
# Epoch 60/100
# 727/727 - 30s - loss: 0.0335 - accuracy: 0.4988
# Epoch 61/100
# 727/727 - 30s - loss: 0.0390 - accuracy: 0.4988
# Epoch 62/100
# 727/727 - 30s - loss: 0.0310 - accuracy: 0.4988
# Epoch 63/100
# 727/727 - 30s - loss: 0.0299 - accuracy: 0.4988
# Epoch 64/100
# 727/727 - 30s - loss: 0.0300 - accuracy: 0.4988
# Epoch 65/100
# 727/727 - 30s - loss: 0.0325 - accuracy: 0.4988
# Epoch 66/100
# 727/727 - 30s - loss: 0.0362 - accuracy: 0.4988
# Epoch 67/100
# 727/727 - 30s - loss: 0.0227 - accuracy: 0.4988
# Epoch 68/100
# 727/727 - 30s - loss: 0.0422 - accuracy: 0.4988
# Epoch 69/100
# 727/727 - 30s - loss: 0.0281 - accuracy: 0.4988
# Epoch 70/100
# 727/727 - 30s - loss: 0.0246 - accuracy: 0.4988
# Epoch 71/100
# 727/727 - 30s - loss: 0.0356 - accuracy: 0.4988
# Epoch 72/100
# 727/727 - 30s - loss: 0.0222 - accuracy: 0.4988
# Epoch 73/100
# 727/727 - 30s - loss: 0.0280 - accuracy: 0.4988
# Epoch 74/100
# 727/727 - 30s - loss: 0.0391 - accuracy: 0.4988
# Epoch 75/100
# 727/727 - 31s - loss: 0.0377 - accuracy: 0.4988
# Epoch 76/100
# 727/727 - 31s - loss: 0.0203 - accuracy: 0.4988
# Epoch 77/100
# 727/727 - 30s - loss: 0.0301 - accuracy: 0.4988
# Epoch 78/100
# 727/727 - 30s - loss: 0.0256 - accuracy: 0.4988
# Epoch 79/100
# 727/727 - 30s - loss: 0.0310 - accuracy: 0.4988
# Epoch 80/100
# 727/727 - 29s - loss: 0.0293 - accuracy: 0.4988
# Epoch 81/100
# 727/727 - 29s - loss: 0.0304 - accuracy: 0.4988
# Epoch 82/100
# 727/727 - 29s - loss: 0.0374 - accuracy: 0.4988
# Epoch 83/100
# 727/727 - 29s - loss: 0.0264 - accuracy: 0.4988
# Epoch 84/100
# 727/727 - 29s - loss: 0.0416 - accuracy: 0.4988
# Epoch 85/100
# 727/727 - 29s - loss: 0.0316 - accuracy: 0.4988
# Epoch 86/100
# 727/727 - 29s - loss: 0.0266 - accuracy: 0.4988
# Epoch 87/100
# 727/727 - 29s - loss: 0.0275 - accuracy: 0.4988
# Epoch 88/100
# 727/727 - 29s - loss: 0.0272 - accuracy: 0.4988
# Epoch 89/100
# 727/727 - 29s - loss: 0.0286 - accuracy: 0.4988
# Epoch 90/100
# 727/727 - 29s - loss: 0.0378 - accuracy: 0.4988
# Epoch 91/100
# 727/727 - 29s - loss: 0.0268 - accuracy: 0.4988
# Epoch 92/100
# 727/727 - 29s - loss: 0.0353 - accuracy: 0.4988
# Epoch 93/100
# 727/727 - 29s - loss: 0.0345 - accuracy: 0.4988
# Epoch 94/100
# 727/727 - 29s - loss: 0.0265 - accuracy: 0.4988
# Epoch 95/100
# 727/727 - 29s - loss: 0.0273 - accuracy: 0.4988
# Epoch 96/100
# 727/727 - 29s - loss: 0.0187 - accuracy: 0.4988
# Epoch 97/100
# 727/727 - 29s - loss: 0.0448 - accuracy: 0.4988
# Epoch 98/100
# 727/727 - 29s - loss: 0.0272 - accuracy: 0.4988
# Epoch 99/100
# 727/727 - 29s - loss: 0.0262 - accuracy: 0.4988
# Epoch 100/100
# 727/727 - 29s - loss: 0.0416 - accuracy: 0.4988
